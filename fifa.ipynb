# %%
import pandas as pd
dados = pd.read_csv('arquivos/fifa.csv')
dados.head()
dados.iloc[2, 2]
dados['total'] = dados['Reactions'] + dados['Acceleration'] + dados['Agility']
dados = dados[['Name', 'Age', 'total']]

# %%
dados.to_csv('arquivos/fifa_novo.csv')

# %%
dados.to_excel('arquivos/fifa_excel.xlsx', index=False)
